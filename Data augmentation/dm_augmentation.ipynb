# %% [markdown]
# # Data augmentation
#
# Data augmentation is the process of altering original data items in a structured way to produce similar data items that differ from the original data item in a precisely defined way. Data augmentation techniques can be applied to textual data, image data, and audio data. In this exercise we will focus on augmentation techniques for text and images.
#
# In order to complete the exercise you need to install two libraries:
#
# ```bash
# bash$ pip install nlpaug
#
# bash$ pip install augmentor
# ```

# %% [markdown]
# ## Augmentation of text
#
# Data augmentation for text can be performed on three levels:
# - character modifications
# - word modifications
# - sentence modifications

# %% [markdown]
# ### Character-level augmentation
#
# There are two primary reasons for doing character-level augmentation:
# - to simulate typing errors
# - to simulate OCR errors
#
# Below we start with a simple example of augmentation that tries to address these two cases.

# %%
from nlpaug.augmenter.char import KeyboardAug

_input = 'Poznan is a medium-sized city on the banks of the Warta river'
_output = KeyboardAug().augment(_input)

print(f"{_input}\n{_output}")
# Out:
# Poznan is a medium-sized city on the banks of the Warta river
# ['PoznQB is a JDdium - sized city on the bwnkE of the Wadfa rige5']

# %% [markdown]
# The `nlpaug` library allows to produce multiple augmentations for a single input, as well as processing a list of texts.

# %%
_input = 'To be or not to be, this is the question'
_output = KeyboardAug().augment(_input, n=5)

print(f"{_input}")

for result in _output:
    print(f"{result}")
# Out:
# To be or not to be, this is the question
# To be or not to be, ^hls is the a Testiom
# To be or not to be, Hhia is the SuectUon
# To be or not to be, th&W is the queshKoB
# To be or not to be, tbiz is the qhes%ioh
# To be or not to be, hbis is the quDwtioJ

# %%
_input = [
    'This is the first sentence',
    'This is the second sentence',
    'This is the third sentence',
]
_output = KeyboardAug().augment(_input)

for original, transformed in zip(_input, _output):
    print(f"{original}\n{transformed}\n")
# Out:
# This is the first sentence
# This is the Vi4st wentSnfe
#
# This is the second sentence
# This is the sedknd seHtenFd
#
# This is the third sentence
# TgKs is the third sDhtenc2

# %% [markdown]
# If the training data for the ML model have been extracted via OCR from images, there is probably a very specific bias in the data. For instance, the lower case letter `l` can be easily mistaken for the digit `1` or for the upper case `I`. Similarly, `9` and `g` are often confused as well as `0` and `O`. `OCRAug` class simulates these types of mistakes.

# %%
from nlpaug.augmenter.char import OcrAug

_input = 'This bottle has the volume of 10 l and it weights 230 g'
_output = OcrAug().augment(_input)

print(f"{_input}\n{_output}")
# Out:
# This bottle has the volume of 10 l and it weights 230 g
# ['This bottle ha8 the volume 0f ID l and it weights 230 g']

# %% [markdown]
# Finally, `nlpaug` allows to introduce random insertions, swaps, and deletions of characters from the source text.

# %%
from nlpaug.augmenter.char import RandomCharAug

_input = 'Imagine all the people living life of peace'

_output_ins = RandomCharAug(action='insert').augment(_input)
_output_sub = RandomCharAug(action='substitute').augment(_input)
_output_swp = RandomCharAug(action='swap').augment(_input)
_output_del = RandomCharAug(action='delete').augment(_input)

print(f"{_input}")
print(f"{_output_ins}\n{_output_sub}\n{_output_swp}\n{_output_del}")
# Out:
# Imagine all the people living life of peace
# ['TINmag@ine all the pseyople living life of HpeMace']
# ['IDwg4ne all the people liTinu life of 3eacj']
# ['Imagine all the pepoel ilivng life of peace']
# ['Imagine all the people lvng fe of pae']

# %% [markdown]
# ### Word-level augmentation
#
# Word-level augmentation can be used in many scenarios depending on the characteristics of the training dataset. Examples of augmentations include:
#
# - substituting a word for an alternative spelling
# - finding a synonym of a word based on word embeddings
# - finding a synonym of a word based on TF-IDF
# - finding a synonym of a word based on contextual word embeddings
# - finding a synonym of a word based on a dictionary
# - randomly splitting words
# - substituting a word for its antonym
#
# Below we will see some of the above scenarios in action.

# %%
from nlpaug.augmenter.word import SpellingAug

_input = 'In a hole in the ground there lived a hobbit'

_output = SpellingAug().augment(_input, n=3)

print(f"{_input}")

for result in _output:
    print(f"{result}")
# Out:
# In a hole in the ground there lived a hobbit
# In a hole in the ground there lived aa habit
# In a hole in da grount there lived a habit
# In as wholes ib the ground there lived a hobbit

# %% [markdown]
# The next example requires you to download the pre-trained word embeddings. We are using `fasttext` Englishl embeddings trained on the Wikipedia corpus. You can download the model from [https://fasttext.cc/docs/en/english-vectors.html](https://fasttext.cc/docs/en/english-vectors.html)

# %%
from nlpaug.augmenter.word import WordEmbsAug

augmenter = WordEmbsAug(model_type='fasttext',
                        model_path='wiki-news-300d-1M.vec',
                        action='substitute'
                       )

_input = 'In a hole in the ground there lived a hobbit'
_output = augmenter.augment(_input)

print(f"{_input}\n{_output}")
# Out:
# In a hole in the ground there lived a hobbit
# ['In a hole in traditional ground having lived a hominin']

# %% [markdown]
# `FastText` or `word2vec` embeddings are static, a given word always receives the same vector, independent of the textual context. If you want to use contextual embeddings, you have to use the BERT family of language models (`bert-base-uncased`, `distilbert-base-uncased`, `roberta-base`, etc.)

# %%
from nlpaug.augmenter.word import ContextualWordEmbsAug

augmenter = ContextualWordEmbsAug(model_path='bert-base-uncased', action='substitute')

_input = 'In a hole in the ground there lived a hobbit'
_output = augmenter.augment(_input)

print(f"{_input}\n{_output}")
# Out:
# In a hole in the ground there lived a hobbit
# ['through a cave in the ground it lived an hobbit']

# %% [markdown]
# Similar functionality can be achieved by using WordNet or PPDB. In order to run the following examples please do the following:
#
# - install `nltk 3.5`
# - download the paraphrase database file from http://paraphrase.org/#/download (use the small size pack)
#
# ```bash
# bash$ pip install nltk==3.5
# ```

# %%
from nlpaug.augmenter.word import SynonymAug

_input = 'Every cloud has a silver lining'
_output = SynonymAug(aug_src='wordnet').augment(_input)

print(f"{_input}\n{_output}")
# Out:
# Every cloud has a silver lining
# ['Every cloud accept a silver liner']

# %% [markdown]
# If you plan to use PDDB database (http://paraphrase.org/#/) then you have to point to the location of the file.

# %%
from nlpaug.augmenter.word import SynonymAug
import os

augmenter = SynonymAug(
    aug_src='ppdb',
    model_path='ppdb-2.0-s-all'
)

_input = 'Every cloud has a silver lining'
_output = augmenter.augment(_input)

print(f"{_input}\n{_output}")
# Out:
# Every cloud has a silver lining
# ['Every cloud works a silver lining']

# %% [markdown]
# An interesting option is to use antonyms for generating alternatives for the training data. Here is a simple example.

# %%
from nlpaug.augmenter.word import AntonymAug

_input = 'I am having a great time!'
_output = AntonymAug().augment(_input)

print(f"{_input}\n{_output}")
# Out:
# I am having a great time!
# ['I differ abstain a great time!']

# %% [markdown]
# Finally, `RandomWordAug` allows us to randomly swap, delete and crop words from the input.

# %%
from nlpaug.augmenter.word import RandomWordAug

_input = 'Once upon a time there was a little bird'

_output_swp = RandomWordAug(action='swap').augment(_input)
_output_del = RandomWordAug(action='delete').augment(_input)
_output_crp = RandomWordAug(action='crop').augment(_input)

print(f"{_input}")
print(f"{_output_swp}\n{_output_del}\n{_output_crp}")
# Out:
# Once upon a time there was a little bird
# ['Upon once a time there a was bird little']
# ['Upon a time there was a little']
# ['Once upon a time little bird']

# %% [markdown]
# There is also a word-level augmenter which performs random splitting of words.

# %%
from nlpaug.augmenter.word import SplitAug

_input = 'In a hole in the ground there lived a hobbit'
_output = SplitAug().augment(_input)

print(f"{_input}\n{_output}")
# Out:
# In a hole in the ground there lived a hobbit
# ['In a h ole in the gro und there liv ed a hobbit']

# %% [markdown]
# Finally, if you want to augment only specific words (for which you know precisely the alternatives), you can use the `ReservedAug`.

# %%
from nlpaug.augmenter.word import ReservedAug

reserved_words = [
    ['FW', 'Fwd', 'F/D', 'Forward'],
    ['Q1', 'Q2', 'Q3', 'Q4']
]

_input = 'Fwd: Sales report for Q1'
_output = ReservedAug(reserved_tokens=reserved_words).augment(_input)

print(f"{_input}\n{_output}")
# Out:
# Fwd: Sales report for Q1
# ['F/D: Sales report for Q2']

# %% [markdown]
# ### Sentence-level augmentation
#
# Sentence-level augmentation uses state-of-the-art contextual word embeddings created by the BERT family of language models. In order to use these models you have to install the following dependencies:
#
# ```bash
# bash$ pip install torch>=1.6.0 transformers>=4.0.0
# ```

# %%
from nlpaug.augmenter.sentence import ContextualWordEmbsForSentenceAug

augmenter = ContextualWordEmbsForSentenceAug(model_path='xlnet-base-cased', temperature=0.5, top_k=50, min_length=200)

_input = 'To be or not to be, this is the question.'
_output = augmenter.augment(_input)

print(f"{_input}\n{_output}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 6
#       3 augmenter = ContextualWordEmbsForSentenceAug(model_path='xlnet-base-cased', temperature=0.5, top_k=50, min_length=200)
#       5 _input = 'To be or not to be, this is the question.'
# ----> 6 _output = augmenter.augment(_input)
#       8 print(f"{_input}\n{_output}")
#
# File /opt/homebrew/lib/python3.11/site-packages/nlpaug/base_augmenter.py:98, in Augmenter.augment(self, data, n, num_thread)
#      96 elif self.__class__.__name__ in ['AbstSummAug', 'BackTranslationAug', 'ContextualWordEmbsAug', 'ContextualWordEmbsForSentenceAug']:
#      97     for _ in range(aug_num):
# ---> 98         result = action_fx(clean_data)
#      99         if isinstance(result, list):
#     100             augmented_results.extend(result)
#
# File /opt/homebrew/lib/python3.11/site-packages/nlpaug/augmenter/sentence/context_word_embs_sentence.py:116, in ContextualWordEmbsForSentenceAug.insert(self, data)
#     113     all_data = [data]
#     115 if self.use_custom_api:
# --> 116     return self._custom_insert(all_data)
#     117 else:
#     118     return self._native_insert(all_data)
#
# File /opt/homebrew/lib/python3.11/site-packages/nlpaug/augmenter/sentence/context_word_embs_sentence.py:191, in ContextualWordEmbsForSentenceAug._custom_insert(self, all_data)
#     189     results = [d + a for d, a in zip(all_data, augmented_texts)]
#     190 elif self.model_type in ['xlnet']:
# --> 191     results = [d + ' ' + self.model.tokenizer.convert_tokens_to_string(a) for d, a in zip(all_data, augmented_texts)]
#     193 return results
#
# File /opt/homebrew/lib/python3.11/site-packages/nlpaug/augmenter/sentence/context_word_embs_sentence.py:191, in <listcomp>(.0)
#     189     results = [d + a for d, a in zip(all_data, augmented_texts)]
#     190 elif self.model_type in ['xlnet']:
# --> 191     results = [d + ' ' + self.model.tokenizer.convert_tokens_to_string(a) for d, a in zip(all_data, augmented_texts)]
#     193 return results
#
# File /opt/homebrew/lib/python3.11/site-packages/transformers/tokenization_utils_fast.py:536, in PreTrainedTokenizerFast.convert_tokens_to_string(self, tokens)
#     535 def convert_tokens_to_string(self, tokens: List[str]) -> str:
# --> 536     return self.backend_tokenizer.decoder.decode(tokens)
#
# TypeError: argument 'tokens': Can't extract `str` to `Vec`

# %% [markdown]
# ### Sequences of augmentations
#
# `nlpaug` allows you to define two modes of sequential augmentations:
# - provide a list of augmentations to be applied sequentially
# - provide a list of augmentations which will randomly be applied

# %%
from nlpaug.flow import Sequential, Sometimes
from nlpaug.util import Action
from nlpaug.augmenter.word import RandomWordAug
from nlpaug.augmenter.char import RandomCharAug

_flow = Sequential(
    [
    RandomCharAug(action=Action.INSERT),
    RandomCharAug(action=Action.SWAP),
    RandomWordAug(action=Action.DELETE),
    ]
)

_input = 'In a hole in the ground there lived a hobbit'
_output = _flow.augment(_input)

print(f"{_input}\n{_output}")
# Out:
# In a hole in the ground there lived a hobbit
# ['A hOvuel in the zRgo * und there a']

# %% [markdown]
# ### Exercise
#
# Use the [IMDB Dataset](https://www.kaggle.com/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews) to create a sample of 100 movie reviews. Then, create a sequence of transformations that are relevant for training the sentiment model. Assume that the reviews have been manually typed on a keyboard. Include character-level, word-level and sentence-level augmentations. In particular, try to augment movie reviews with relevant synonyms.

# %%
import pandas as pd

df = pd.read_csv("IMDB Dataset.csv")
films = df.sample(100)

_flow = Sequential(
    [
        KeyboardAug(),
        SynonymAug(
            aug_src='ppdb',
            model_path='ppdb-2.0-s-all'
        ),
        ContextualWordEmbsForSentenceAug(model_path='xlnet-base-cased', temperature=0.5, top_k=50, min_length=200)
    ]
)

films['augumented'] = films['review'].apply(lambda x: _flow.augment(x))
films
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 17
#       4 films = df.sample(100)
#       6 _flow = Sequential(
#       7     [
#       8         KeyboardAug(),
#    (...)
#      14     ]
#      15 )
# ---> 17 films['augumented'] = films['review'].apply(lambda x: _flow.augment(x))
#      18 films
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[48], line 17, in <lambda>(x)
#       4 films = df.sample(100)
#       6 _flow = Sequential(
#       7     [
#       8         KeyboardAug(),
#    (...)
#      14     ]
#      15 )
# ---> 17 films['augumented'] = films['review'].apply(lambda x: _flow.augment(x))
#      18 films
#
# File /opt/homebrew/lib/python3.11/site-packages/nlpaug/flow/pipeline.py:58, in Pipeline.augment(self, data, n, num_thread)
#      56 augmented_results = []
#      57 if num_thread == 1:
# ---> 58     augmented_results = [self._augment(data) for _ in range(n)]
#      59 else:
#      60     if self.device == 'cpu':
#
# File /opt/homebrew/lib/python3.11/site-packages/nlpaug/flow/pipeline.py:58, in <listcomp>(.0)
#      56 augmented_results = []
#      57 if num_thread == 1:
# ---> 58     augmented_results = [self._augment(data) for _ in range(n)]
#      59 else:
#      60     if self.device == 'cpu':
#
# File /opt/homebrew/lib/python3.11/site-packages/nlpaug/flow/pipeline.py:101, in Pipeline._augment(self, data, n, num_thread)
#      99 aug.include_detail = parent_include_detail  # Follow parent setting
#     100 aug.parent_change_seq = self.parent_change_seq+len(change_logs)
# --> 101 augmented_data = aug.augment(augmented_data, n=n, num_thread=num_thread)
#     102 if aug.include_detail:
#     103     # (augmented_data, change_log)
#     104     change_logs.extend(augmented_data[1])
#
# File /opt/homebrew/lib/python3.11/site-packages/nlpaug/base_augmenter.py:98, in Augmenter.augment(self, data, n, num_thread)
#      96 elif self.__class__.__name__ in ['AbstSummAug', 'BackTranslationAug', 'ContextualWordEmbsAug', 'ContextualWordEmbsForSentenceAug']:
#      97     for _ in range(aug_num):
# ---> 98         result = action_fx(clean_data)
#      99         if isinstance(result, list):
#     100             augmented_results.extend(result)
#
# File /opt/homebrew/lib/python3.11/site-packages/nlpaug/augmenter/sentence/context_word_embs_sentence.py:116, in ContextualWordEmbsForSentenceAug.insert(self, data)
#     113     all_data = [data]
#     115 if self.use_custom_api:
# --> 116     return self._custom_insert(all_data)
#     117 else:
#     118     return self._native_insert(all_data)
#
# File /opt/homebrew/lib/python3.11/site-packages/nlpaug/augmenter/sentence/context_word_embs_sentence.py:191, in ContextualWordEmbsForSentenceAug._custom_insert(self, all_data)
#     189     results = [d + a for d, a in zip(all_data, augmented_texts)]
#     190 elif self.model_type in ['xlnet']:
# --> 191     results = [d + ' ' + self.model.tokenizer.convert_tokens_to_string(a) for d, a in zip(all_data, augmented_texts)]
#     193 return results
#
# File /opt/homebrew/lib/python3.11/site-packages/nlpaug/augmenter/sentence/context_word_embs_sentence.py:191, in <listcomp>(.0)
#     189     results = [d + a for d, a in zip(all_data, augmented_texts)]
#     190 elif self.model_type in ['xlnet']:
# --> 191     results = [d + ' ' + self.model.tokenizer.convert_tokens_to_string(a) for d, a in zip(all_data, augmented_texts)]
#     193 return results
#
# File /opt/homebrew/lib/python3.11/site-packages/transformers/tokenization_utils_fast.py:536, in PreTrainedTokenizerFast.convert_tokens_to_string(self, tokens)
#     535 def convert_tokens_to_string(self, tokens: List[str]) -> str:
# --> 536     return self.backend_tokenizer.decoder.decode(tokens)
#
# TypeError: argument 'tokens': Can't extract `str` to `Vec`

# %% [markdown]
# ## Augmentation for images
#
# We will experiment with `Augmentor` library to perform random augmentations of images. `Augmentor` allows you to define a _pipeline_ of augmentations. Each augmentation has a parameter `probability` which defines, how probable it is that the augmentation will be applied.
#
# For this part of the exercise we will use the [Face Mask Detection dataset](https://www.kaggle.com/sshikamaru/face-mask-detection) from Kaggle Datasets.
#
# After downloading and unpacking the dataset, please create an additional directory with a single image for demonstration purposes.
#
# ```bash
# bash$ mkdir images/example
# bash$ cp images/train/smartmi-3pcs-filter-mask-pm25-haze-dustproof-mask-with-vent_jpg.rf.c5b0c5b7666032c5b4634740eafde234.jpg images/example/image.jpg
# ```

# %%
import Augmentor

path_to_files = 'images/example/'

p = Augmentor.Pipeline(path_to_files)
p.status()
# Out:
# Initialised with 1 image(s) found.
# Output directory set to images/example/output.Operations: 0
# Images: 1
# Classes: 1
# 	Class index: 0 Class label: example
# Dimensions: 1
# 	Width: 416 Height: 416
# Formats: 1
# 	 JPEG
#
# You can remove operations using the appropriate index and the remove_operation(index) function.

# %% [markdown]
# We will start with a very simple horizontal mirror flip of images

# %%
p.flip_left_right(probability=0.9)

p.sample(5)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Processing <PIL.Image.Image image mode=RGB size=416x416 at 0x2E4F36950>: 100%|██████████| 5/5 [00:00<00:00, 558.85 Samples/s]

# %%
from IPython.display import Image, display, HTML

from glob import glob

def make_html(image):
     return f"<img src='{image}' style='display:inline;margin:1px;width:100px'/>"
    
original_image = "images/example/image.jpg"
transformed_images = glob("images/example/output/*.jpg")

display(Image(filename=original_image, width=100, height=100))

html_images = ''.join([make_html(x) for x in transformed_images])
display(HTML(html_images))
# Out:
# <img src='images/example/output/example_original_image.jpg_99fc11e6-9b25-444e-9e49-5a3c799cef60.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_0a68895e-49e3-4733-b7f5-43673599f016.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_0343e7bc-46bb-46f9-85dd-d927cca3fbd1.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_fc5e6b97-0e9a-4fd8-8396-1ae37bead562.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_42e1c28a-e988-4972-885f-89fc674406b5.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_877e4259-77f4-4699-8d2e-e1c8cdeacbc4.jpg' style='display:inline;margin:1px;width:100px'/>

# %% [markdown]
# Next, we will illustrate some more transformations available in the `Augmentor` library

# %%
# !rm images/example/output/*
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# rotation

path_to_files = 'images/example'

p = Augmentor.Pipeline(path_to_files)

# p.rotate(probability=0.5, max_left_rotation=25, max_right_rotation=25)
# p.rotate180(probability=0.5)
# p.rotate90(probability=0.5)
p.rotate_random_90(probability=0.5)

p.sample(10)

original_image = 'images/example/image.jpg'
transformed_images = glob('images/example/output/*.jpg')

display(Image(filename=original_image, width=100, height=100))

html_images = ''.join([make_html(x) for x in transformed_images])
display(HTML(html_images))
# Out:
# Initialised with 1 image(s) found.
# Output directory set to images/example/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416 at 0x2E97C9310>: 100%|██████████| 10/10 [00:00<00:00, 561.16 Samples/s]
# <img src='images/example/output/example_original_image.jpg_3fbdd41d-7f0d-4b80-ae9a-e38fb4522115.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_d4a0402c-837e-4101-96af-de11d60eafb5.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_031cefea-9e42-455e-8260-7b6d73ed3738.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_491b30d9-ee76-4921-891d-d698a1ecd773.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_1b1a58ac-3729-46e9-9d9b-552a16ddeb0a.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_5c9c797b-3746-4f67-ba99-a92b75c87525.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_b982a86d-0e54-4539-b35c-487d868fe067.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_81e412cf-11bd-4337-a6c2-e2656f8c39c8.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_3b7c7fc4-79a1-4b3b-97d5-c5ee8e36a93a.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_1fac1523-d3f6-4477-988f-5438e66c7c70.jpg' style='display:inline;margin:1px;width:100px'/>

# %%
# !rm images/example/output/*
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# zooming

path_to_files = 'images/example'

p = Augmentor.Pipeline(path_to_files)

# p.zoom(probability=0.5, min_factor=1.1, max_factor=2.0)
p.zoom_random(probability=0.5, percentage_area=0.5)

p.sample(10)

original_image = 'images/example/image.jpg'
transformed_images = glob('images/example/output/*.jpg')

display(Image(filename=original_image, width=100, height=100))

html_images = ''.join([make_html(x) for x in transformed_images])
display(HTML(html_images))
# Out:
# Initialised with 1 image(s) found.
# Output directory set to images/example/output.
# Processing <PIL.Image.Image image mode=RGB size=416x416 at 0x2E9650290>: 100%|██████████| 10/10 [00:00<00:00, 424.86 Samples/s]
# <img src='images/example/output/example_original_image.jpg_a9601778-9fab-48a0-b9bf-36ed6495300c.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_4109013f-e6df-42b3-aa05-d63260200f0d.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_554cddbd-7c0e-4997-8759-c0d3185ea028.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_14b66408-40a2-4eec-b4b5-2f73d0c8afd0.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_37319677-8f33-4181-b173-825a5187d49e.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_b677decb-54ae-4cda-adbc-2b10cd39444e.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_89d2146e-318d-458b-a1d0-9d5d194a6d94.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_0aed83a5-e22b-472d-87e6-1417a407e33f.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_21709926-8264-4f49-bc04-a8437595487a.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_47a60b84-35e0-4a79-9777-9e6ddb07ac67.jpg' style='display:inline;margin:1px;width:100px'/>

# %%
# !rm images/example/output/*
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# perspective skewing

path_to_files = 'images/example'

p = Augmentor.Pipeline(path_to_files)

# p.skew_tilt(probability=0.5)
# p.skew_left_right(probability=0.5)
# p.skew_top_bottom(probability=0.5)
p.skew_corner(probability=0.5)

p.sample(10)

original_image = 'images/example/image.jpg'
transformed_images = glob('images/example/output/*.jpg')

display(Image(filename=original_image, width=100, height=100))

html_images = ''.join([make_html(x) for x in transformed_images])
display(HTML(html_images))
# Out:
# Initialised with 1 image(s) found.
# Output directory set to images/example/output.
# Processing <PIL.Image.Image image mode=RGB size=416x416 at 0x2E9848B90>: 100%|██████████| 10/10 [00:00<00:00, 349.95 Samples/s]
# <img src='images/example/output/example_original_image.jpg_5cdfd93d-3a80-4294-86db-96a814287ddb.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_8985b296-62e8-4037-80f2-d53ad6849f42.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_5d061d19-7d4d-48b2-89cf-87d286571498.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_cda0e786-d927-4956-8c5c-e67372c47018.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_fcca4ea1-e1d0-4aba-add0-b8583aa841d3.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_27b8f22d-5971-4467-8fea-b2edab2685e4.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_8391fa7c-dfd8-4637-a624-39da343888ed.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_b31a028c-bfc0-4194-8de9-589cee02b921.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_3a5af0ac-ba8c-4cf7-9748-5ab3f37457a4.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_0fa29984-300b-4c5c-b623-ff17f61be50b.jpg' style='display:inline;margin:1px;width:100px'/>

# %%
# !rm images/example/output/*
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# elastic distortions

path_to_files = 'images/example'

p = Augmentor.Pipeline(path_to_files)

# p.random_distortion(probability=0.9, grid_width=5, grid_height=5, magnitude=10)
# p.random_color(probability=0.5, min_factor=0.1, max_factor=0.5)
# p.random_contrast(probability=0.5, min_factor=0.1, max_factor=0.5)
# p.random_erasing(probability=0.5, rectangle_area=0.25)
p.random_brightness(probability=0.5, min_factor=0.1, max_factor=0.5)

p.sample(10)

original_image = 'images/example/image.jpg'
transformed_images = glob('images/example/output/*.jpg')

display(Image(filename=original_image, width=100, height=100))

html_images = ''.join([make_html(x) for x in transformed_images])
display(HTML(html_images))
# Out:
# Initialised with 1 image(s) found.
# Output directory set to images/example/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416 at 0x2E97C8C90>: 100%|██████████| 10/10 [00:00<00:00, 568.08 Samples/s]
# <img src='images/example/output/example_original_image.jpg_bff1bf45-130d-4777-b1bf-2f7797594eac.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_bba07a26-6a9c-443e-aadc-12eab69f6d06.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_e61bcc28-5203-426d-9516-549865d2c252.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_d2bb191d-cf46-4079-aa26-85cdc2fe14bb.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_05c7c511-feaa-449c-bd22-aba68a03e165.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_ad83fcb5-41a2-4885-a907-2cda0dea5ffa.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_f1233583-19b0-4d49-8886-d659c3d6ea53.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_be550875-9e2e-4fbf-a2d5-041d6d11e581.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_613dfefe-76fc-4768-91f3-916f7666d0ef.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_1dafcf31-1fdb-450b-a20b-16fe2e23397d.jpg' style='display:inline;margin:1px;width:100px'/>

# %%
# !rm images/example/output/*
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# shearing

path_to_files = 'images/example'

p = Augmentor.Pipeline(path_to_files)

p.shear(probability=0.5, max_shear_left=25, max_shear_right=25)

p.sample(10)

original_image = 'images/example/image.jpg'
transformed_images = glob('images/example/output/*.jpg')

display(Image(filename=original_image, width=100, height=100))

html_images = ''.join([make_html(x) for x in transformed_images])
display(HTML(html_images))
# Out:
# Initialised with 1 image(s) found.
# Output directory set to images/example/output.
# Processing <PIL.Image.Image image mode=RGB size=416x416 at 0x2E82B03D0>: 100%|██████████| 10/10 [00:00<00:00, 306.96 Samples/s]
# <img src='images/example/output/example_original_image.jpg_40a70973-ede5-4382-83d0-83c6631f8e10.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_acd4b31b-e0da-4676-9cb3-5b99be5d3b87.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_93d86e73-928d-4c9c-a40f-fb3a1d313a4e.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_f1d294a0-3b2f-4c3a-9dd5-3d9d58e6ae21.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_edd1475b-52ce-4041-8cc6-912a44c4a294.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_bf62fc3a-e190-4022-914d-4c8ae71c3937.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_23e95885-ee7a-427b-b0f3-4bc9742893ac.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_2d3451e5-c6b4-4b00-8f4a-622de8b48549.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_6859e0d1-8419-4050-9d3a-1ac8d18b58c3.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_04ab6ba0-c650-4785-820e-12b6118e1359.jpg' style='display:inline;margin:1px;width:100px'/>

# %%
# !rm images/example/output/*
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# cropping

path_to_files = 'images/example'

p = Augmentor.Pipeline(path_to_files)

# p.crop_centre(probability=0.5, percentage_area=0.5)
# p.crop_by_size(probability=0.5, width=100, height=100)
p.crop_random(probability=0.5, percentage_area=0.5)

p.sample(10)

original_image = 'images/example/image.jpg'
transformed_images = glob('images/example/output/*.jpg')

display(Image(filename=original_image, width=100, height=100))

html_images = ''.join([make_html(x) for x in transformed_images])
display(HTML(html_images))
# Out:
# Initialised with 1 image(s) found.
# Output directory set to images/example/output.
# Processing <PIL.Image.Image image mode=RGB size=208x208 at 0x2E97C9750>: 100%|██████████| 10/10 [00:00<00:00, 806.46 Samples/s]
# <img src='images/example/output/example_original_image.jpg_b057e93b-8f0c-4854-af46-7093339928b6.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_f1b98e98-e3a1-4c12-a576-babd8179f1f6.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_197796e0-c073-4a58-988c-556c84cdf731.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_2b208526-0adf-4b5b-8e55-2bdfb6b80d62.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_af15fa2b-b0c1-46b9-806f-c68d1ca5dbe9.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_6faacbc3-648b-49cb-bcef-360ff113b1e3.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_48122cb4-d949-4148-b799-b62535fa854c.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_5e198380-373f-4602-b207-47430ca57e4b.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_45d4a682-08bb-4776-a193-1043a1afe152.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/example/output/example_original_image.jpg_69368fb4-8318-47db-bc63-e35c4b11635e.jpg' style='display:inline;margin:1px;width:100px'/>

# %% [markdown]
# If you wish to process each image in the pipeline exactly once, use `process()`

# %%
# !rm images/example/output/*
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# resizing

def make_html_original_size(image):
     return f"<img src='{image}' style='display:inline;margin:1px'/>"
    
path_to_files = 'images/example'

p = Augmentor.Pipeline(path_to_files)

p.resize(probability=1.0, width=100, height=100)

p.process()

original_image = 'images/example/image.jpg'
transformed_images = glob('images/example/output/*.jpg')

display(Image(filename=original_image))

html_images = ''.join([make_html_original_size(x) for x in transformed_images])
display(HTML(html_images))
# Out:
# Initialised with 1 image(s) found.
# Output directory set to images/example/output.
# Processing <PIL.Image.Image image mode=RGB size=100x100 at 0x2E82B03D0>: 100%|██████████| 1/1 [00:00<00:00, 283.78 Samples/s]
# <img src='images/example/output/example_original_image.jpg_a01f624d-5fd5-43f4-9c4a-eaf51746c488.jpg' style='display:inline;margin:1px'/>

# %% [markdown]
# ### Exercise
#
# Use the `images/train` folder to create a set of transformations of images. When designing the augmentation pipeline, consider the main aim of the augmentation: to improve the model for face mask detection.

# %%
path_to_files = 'images/train'

p = Augmentor.Pipeline(path_to_files)

p.random_distortion(probability=0.9, grid_width=5, grid_height=5, magnitude=10)
p.random_color(probability=0.5, min_factor=0.1, max_factor=0.5)
p.random_contrast(probability=0.5, min_factor=0.1, max_factor=0.5)
p.random_erasing(probability=0.3, rectangle_area=0.15)
p.random_brightness(probability=0.5, min_factor=0.1, max_factor=0.5)
p.crop_random(probability=0.35, percentage_area=0.5)
p.skew_tilt(probability=0.4)
p.zoom_random(probability=0.4, percentage_area=0.85)
p.rotate(probability=0.5, max_left_rotation=25, max_right_rotation=25)

p.process()

transformed_images = glob('images/train/output/*.jpg')

html_images = ''.join([make_html(x) for x in transformed_images])
display(HTML(html_images))
# Out:
# Initialised with 105 image(s) found.
# Output directory set to images/train/output.
# Processing <PIL.Image.Image image mode=RGB size=208x207 at 0x2E9FD3810>: 100%|██████████| 105/105 [00:00<00:00, 186.26 Samples/s]
# <img src='images/train/output/train_original_sdfsdfsfff_jpg.rf.c4aca6cc392df43f61e14ac002741ab6.jpg_1c99619a-22d5-4f51-a957-ba8d3b37750a.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/train/output/train_original_unnamed_jpg.rf.638850185c6f05a027f34188518f6a9e.jpg_a731b82a-c8c5-4143-88a6-87662db76fd5.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/train/output/train_original_1422808187-3291816118_jpg.rf.d9c28ba7c110caac049036d25e367b65.jpg_6cb76807-de1b-4a14-b727-f7c0b3d2c013.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/train/output/train_original_130624011830-malaysia-smog-students-horizontal-large-gallery_jpg.rf.52c2d92bc918a8bf50e76895031ec3a0.jpg_0b36043a-dea4-4091-b62a-b72560fb1254.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/train/output/train_original_US-expands-coronavirus-screenings-United-suspends-some-flights-to-China_jpg.rf.1cf554343f0453f6e0a1bd2781cebea9.jpg_8ece7694-4908-452d-8a91-b36da31ac8e2.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/train/output/train_original_skynews-coronavirus-london-fashion-week_4920359_jpg.rf.cf79aa98be9f8687d550dc35caf9edb6.jpg_073281a8-a7ef-4ae9-98eb-603222f81703.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/train/output/train_original_PRI_129079114_1580299603_195_jpg.rf.4906d1ce61ad9a5c86ccfe7e4e261159.jpg_d6d6c569-bc3a-47de-9da4-18ffa6aeef62.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/train/output/train_original_w1240-p16x9-6f1db5e0460631cfa98d2d6d8032942f81700bb0_jpg.rf.8c642180c2f1fc98109dad7ff09fe24c.jpg_da5c71fa-5f64-47de-8e07-67c1a35789cd.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/train/output/train_original_1_13_jpg.rf.53ab50cc136587dec9d42678014977f1.jpg_445b6fc9-2e1b-4284-876f-cb71e3110d1e.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/train/output/train_original_soooo_jpg.rf.accf5a6d0b0fe444b354a2d293821715.jpg_b5bbfe2b-ee88-4c9f-af2a-ce275f9e6ccd.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/train/output/train_original_UDD3JG3E4JFQ5KSFNGQQ5REINU_jpg.rf.407dec06f156a19662ff3e2cb2719dce.jpg_1b561fdb-8178-416a-8be0-7e70d924403f.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/train/output/train_original_1580166133-5b61094cac11561b0cbe09826e32a924_jpg.rf.7bdada2e62db2019a9a2f936083467c1.jpg_9e4a946f-5d65-4e65-8863-c54b53243497.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/train/output/train_original_11893820-3x2-xlarge_jpg.rf.ff6ffd94fa9e0d9dcfcc97380f0aede5.jpg_2109ed51-8ae2-4cdf-a7d0-72d1b669ba30.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/train/output/train_original_w1240-p16x9-5f8aa310737f8e0e6c43d95a68a82b03b6f60106_jpg.rf.104bedd5b3bad4a0d0a453203e0617a3.jpg_f373c0ec-feca-48eb-86e6-01c10709da18.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/train/output/train_original_ST_20170401_EASAND_3046471_jpg.rf.53b81c9038b86e2964978d3d9eefea8f.jpg_f8fba4ac-478a-4ecd-8b88-2120ef85e2b4.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/train/output/train_original_RTX1GIDS_jpg.rf.5b4032f806a5d6f517ee374f27bd1f63.jpg_4e513de6-37c4-4016-9351-64a081557a1a.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/train/output/train_original_soo(1)_jpg.rf.d722163e3c3e0b9f1e4b7a73ea6893cb.jpg_303fe885-ba3f-4004-9a06-6a429cacf63d.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/train/output/train_original_1580053154-5839_jpg.rf.b5682ce5d695469972b6b564e9d1f0ef.jpg_c8674873-2b76-4104-babd-dbf7d5c83eca.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/train/output/train_original_000_1ov3n5_0_jpeg.rf.a23f1c89491779996f4519858277a4e0.jpg_42db647e-be78-423f-b1da-8752aa161bd8.jpg' style='display:inline;margin:1px;width:100px'/><img src='images/train/output/train_original_rally-against-an-anti-mask-law-meant-to-d ...

# %%
# !rm images/train/output/*
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %% [markdown]
# ## Augmentation for imbalanced datasets
#
# One situation where augmentation is very helpful is the classification of highly imbalanced datasets. In order to increase the number of instances in the under-represented class we can augment the data by oversampling. Synthetic Minority Oversampling Technique (SMOTE) is a very popular approach to such augmentation.
#
# Before proceeding to examples, make sure you have `imbalanced-learn` library installed:
#
# ```bash
# $bash pip install imblearn
# ```

# %% [markdown]
# We will begin by generating a synthetic imbalanced dataset.

# %%
from sklearn.datasets import make_classification

X, y = make_classification(n_features=2, n_redundant=0, n_informative=1, n_clusters_per_class=1, n_samples=2000, weights=[0.95, 0.05], class_sep=1)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10))
plt.scatter(X[:, 0], X[:, 1], c=y)

# %% [markdown]
# The idea of SMOTE is to find all k-nearest neighbors of each minority class point, and to generate synthetic points laying half-way between each pair of points.

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(sampling_strategy=1.0, k_neighbors=3)
X_smote, y_smote = smote.fit_resample(X, y)

# %%
plt.figure(figsize=(15,10))
plt.scatter(X_smote[:, 0], X_smote[:, 1], c=y_smote)

# %% [markdown]
# SMOTE creates synthetic datapoints between all examples of the minority class. A variation of the method, called Borderline-SMOTE, generates the synthetic examples only along the decision boundary between the classes

# %%
from imblearn.over_sampling import BorderlineSMOTE

bsmote = BorderlineSMOTE(sampling_strategy=0.5, k_neighbors=3, m_neighbors=10)
X_bsmote, y_bsmote = bsmote.fit_resample(X, y)

# %%
plt.figure(figsize=(15,10))
plt.scatter(X_bsmote[:, 0], X_bsmote[:, 1], c=y_bsmote)

# %% [markdown]
# Finally, Adaptive Syntheic (AdaSyn) method verifies if a minority class point lies close to majority class points and generates synthetic examples in these areas to increase the local density of the minority class

# %%
from imblearn.over_sampling import ADASYN

adasyn = ADASYN(sampling_strategy=0.25, n_neighbors=3)
X_adasyn, y_adasyn = adasyn.fit_resample(X, y)

# %%
plt.figure(figsize=(15,10))
plt.scatter(X_adasyn[:, 0], X_adasyn[:, 1], c=y_adasyn)

# %% [markdown]
# ### Exercise
#
# Load the Iris dataset from `sklearn.datasets` and remove 90% of the *virginica* flowers. Use SMOTE or Borderline-SMOTE to re-generate examples of virginica. Visualize your results

# %%
from sklearn.datasets import load_iris

iris = load_iris(as_frame=True)
X = iris.data.values
y = iris.target.values

plt.figure(figsize=(15,10))
plt.scatter(X[:, 0], X[:,1], c=y)

iris = iris.frame
iris = iris.drop(iris[iris['target'] == 2].sample(frac=.9).index)

X = iris.drop('target', axis=1).values
y = iris.target.values

print(len(iris[iris['target'] == 0]))
print(len(iris[iris['target'] == 1]))
print(len(iris[iris['target'] == 2]))

bsmote = BorderlineSMOTE(sampling_strategy={0:50, 1:50, 2:50}, k_neighbors=4, m_neighbors=10)
X_bsmote, y_bsmote = bsmote.fit_resample(X, y)

print()
print(len(y_bsmote[y_bsmote == 0]))
print(len(y_bsmote[y_bsmote == 1]))
print(len(y_bsmote[y_bsmote == 2]))

plt.figure(figsize=(15,10))
plt.scatter(X_bsmote[:, 0], X_bsmote[:,1], c=y_bsmote)
# Out:
# 50
# 50
# 5
#
# 50
# 50
# 50
